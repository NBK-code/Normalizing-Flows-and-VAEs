# %% [markdown]
# <a href="https://colab.research.google.com/github/NBK-code/Normalizing-Flows-and-VAEs/blob/main/Generalization_in_VAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_probability as tfp
tfd = tfp.distributions
tfpl = tfp.layers

import random
from sklearn.model_selection import train_test_split

from tensorflow.keras import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Reshape, Concatenate
from tensorflow.keras.layers import Conv2D, UpSampling2D, BatchNormalization

# %%
import pathlib
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from zipfile import ZipFile
file_name = '2_images.zip'

with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done!')
# Out:
# Done!

# %%
data_dir = pathlib.Path('/content/2_images')

# %%
print('The number of images:', len(list(data_dir.glob('*.png'))))
# Out:
# The number of images: 3000

# %%
images_dict = {
    '2_images': list(data_dir.glob('*'))
}

# %%
X_train = []

for category, images in images_dict.items():
    for image in images:
        img = cv2.imread(str(image))
        resized_img = cv2.resize(img,(64,64))
        X_train.append(resized_img)

# %%
len(X_train)
# Out:
# 3000

# %%
plt.imshow(X_train[11])

# %%
image_data = np.array(X_train)

# %%
image_data.shape
# Out:
# (3000, 64, 64, 3)

# %%
image_data[0].shape
# Out:
# (64, 64, 3)

# %%
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b

    return gray

# %%
gray_images = []

for image in image_data:
  gray_image = rgb2gray(image)
  gray_images.append(gray_image)

# %%
plt.imshow(gray_images[101], cmap='gray')

# %%
# Train and validation data split

train_images, val_images = train_test_split(image_data, test_size = 0.1)

# %%
print(train_images.shape)
print(val_images.shape)
# Out:
# (2700, 64, 64, 3)
# (300, 64, 64, 3)

# %%
# Create train and validation datasets

train_dataset = tf.data.Dataset.from_tensor_slices(train_images)
val_dataset = tf.data.Dataset.from_tensor_slices(val_images)

# %%
# Function to scale images

def scale_images(image):
  return tf.cast(image, tf.float32)/255.0

# %%
# Apply scale function to the datasets

train_dataset = train_dataset.map(scale_images)
val_dataset = val_dataset.map(scale_images)

# %%
# Function to return a tuple

def return_tuple(image):
  return image, image

# %%
# Apply tuple function to the datasets

train_dataset = train_dataset.map(return_tuple)
val_dataset = val_dataset.map(return_tuple)

# %%
# Shuffle the datasets

train_dataset = train_dataset.shuffle(1000)

# %%
# Batch the datasets

train_dataset = train_dataset.batch(20, drop_remainder=True)
val_dataset = val_dataset.batch(20, drop_remainder=True)

# %%
print(train_dataset.element_spec)
print(val_dataset.element_spec)
# Out:
# (TensorSpec(shape=(20, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(20, 64, 64, 3), dtype=tf.float32, name=None))
# (TensorSpec(shape=(20, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(20, 64, 64, 3), dtype=tf.float32, name=None))

# %%
# Function to get prior

def get_prior(latent_dim):

  loc = tf.zeros(shape = (latent_dim,))
  prior = tfd.MultivariateNormalDiag(loc = loc)

  return prior

# %%
def get_encoder(latent_dim, prior_dist):
    
    encoder = Sequential([
        Conv2D(16, (4,4), activation = 'relu', strides = (2,2), padding = 'SAME', 
               input_shape = (64, 64, 3)),
        BatchNormalization(),
        Conv2D(32, (4,4), activation = 'relu', strides = (2,2), padding = 'SAME', 
               input_shape = (64, 64, 3)),
        BatchNormalization(),
        Conv2D(64, (4,4), activation = 'relu', strides = (2,2), padding = 'SAME'),
        BatchNormalization(),
        Conv2D(256, (4,4), activation = 'relu', strides = (2,2), padding = 'SAME'),
        BatchNormalization(),
        Flatten(),
        Dense(tfpl.MultivariateNormalTriL.params_size(latent_dim)),
        tfpl.MultivariateNormalTriL(latent_dim,
                                    activity_regularizer = tfpl.KLDivergenceRegularizer(prior_dist, 
                                                  weight = 1.0,
                                                  use_exact_kl = False, 
                                                  test_points_fn = lambda q: q.sample(3), 
                                                  test_points_reduce_axis = None))        
    ])
    
    return encoder

# %%
# Function to get decoder

def get_decoder(latent_dim):
    
    decoder = Sequential([
        Dense(2304, activation = 'relu', input_shape = (latent_dim,)),
        Reshape((3,3,256)),
        UpSampling2D((2,2)),
        Conv2D(64, (3,3), activation = 'relu', padding = 'SAME'),
        UpSampling2D((2,2)),
        Conv2D(64, (3,3), activation = 'relu', padding = 'SAME'),
        UpSampling2D((2,2)),
        Conv2D(32, (3,3), activation = 'relu', padding = 'SAME'),
        UpSampling2D((2,2)),
        Conv2D(32, (3,3), activation = 'relu', padding = 'SAME'),
        UpSampling2D((2,2)),
        Conv2D(3, (3,3), padding = 'SAME'),
        Flatten(),
        Dense(tfpl.IndependentBernoulli.params_size(event_shape = (64, 64, 3))),
        tfpl.IndependentBernoulli(event_shape = (64, 64, 3))
    ])
    
    return decoder

# %%
# Latent Dimension

latent_dim = 2

# %%
# Encoder summary

prior_dist = get_prior(latent_dim)

encoder = get_encoder(latent_dim, prior_dist)

encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 16)        784
#
#  batch_normalization (BatchN  (None, 32, 32, 16)       64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 32)        8224
#
#  batch_normalization_1 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          32832
#
#  batch_normalization_2 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 256)         262400
#
#  batch_normalization_3 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 5)                 20485
#
#  multivariate_normal_tri_l (  ((None, 2),              0
#  MultivariateNormalTriL)      (None, 2))
#
# =================================================================
# Total params: 326,197
# Trainable params: 325,461
# Non-trainable params: 736
# _________________________________________________________________

# %%
# Decoder summary

decoder = get_decoder(latent_dim)

decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 2304)              6912
#
#  reshape (Reshape)           (None, 3, 3, 256)         0
#
#  up_sampling2d (UpSampling2D  (None, 6, 6, 256)        0
#  )
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 64)          147520
#
#  up_sampling2d_1 (UpSampling  (None, 12, 12, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 64)        36928
#
#  up_sampling2d_2 (UpSampling  (None, 24, 24, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 24, 24, 32)        18464
#
#  up_sampling2d_3 (UpSampling  (None, 48, 48, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 48, 48, 32)        9248
#
#  up_sampling2d_4 (UpSampling  (None, 96, 96, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 96, 96, 3)         867
#
#  flatten_1 (Flatten)         (None, 27648)             0
#
#  dense_2 (Dense)             (None, 12288)             339750912
#
#  independent_bernoulli (Inde  ((None, 64, 64, 3),      0
#  pendentBernoulli)            (None, 64, 64, 3))
#
# =================================================================
# Total params: 339,970,851
# Trainable params: 339,970,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Create VAE model

VAE = Model(inputs=encoder.inputs, outputs=decoder(encoder.outputs))

# %%
# VAE summary

VAE.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 64, 64, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 16)        784
#
#  batch_normalization (BatchN  (None, 32, 32, 16)       64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 32)        8224
#
#  batch_normalization_1 (Batc  (None, 16, 16, 32)       128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          32832
#
#  batch_normalization_2 (Batc  (None, 8, 8, 64)         256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 256)         262400
#
#  batch_normalization_3 (Batc  (None, 4, 4, 256)        1024
#  hNormalization)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 5)                 20485
#
#  multivariate_normal_tri_l (  ((None, 2),              0
#  MultivariateNormalTriL)      (None, 2))
#
#  sequential_1 (Sequential)   (None, 64, 64, 3)         339970851
#
# =================================================================
# Total params: 340,297,048
# Trainable params: 340,296,312
# Non-trainable params: 736
# _________________________________________________________________

# %%
# Loss function

def reconstruction_loss(batch_of_images, decoding_dist):
    
    return tf.reduce_mean(-decoding_dist.log_prob(batch_of_images))

# %%
# Define optimizer and compile 

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
VAE.compile(optimizer=optimizer, loss=reconstruction_loss)

# %%
# Train the VAE model

history = VAE.fit(train_dataset, validation_data = val_dataset, epochs=60, verbose = True)
# Out:
# Epoch 1/60
# 135/135 [==============================] - 12s 87ms/step - loss: 367.3692 - val_loss: 893.9797
# Epoch 2/60
# 135/135 [==============================] - 12s 88ms/step - loss: 364.3318 - val_loss: 1261.9668
# Epoch 3/60
# 135/135 [==============================] - 12s 88ms/step - loss: 372.3689 - val_loss: 2115.5757
# Epoch 4/60
# 135/135 [==============================] - 12s 88ms/step - loss: 372.6219 - val_loss: 825.8702
# Epoch 5/60
# 135/135 [==============================] - 12s 89ms/step - loss: 357.4337 - val_loss: 1794.1869
# Epoch 6/60
# 135/135 [==============================] - 12s 88ms/step - loss: 366.4309 - val_loss: 957.8371
# Epoch 7/60
# 135/135 [==============================] - 12s 88ms/step - loss: 363.7897 - val_loss: 1766.8738
# Epoch 8/60
# 135/135 [==============================] - 12s 89ms/step - loss: 365.3524 - val_loss: 875.5721
# Epoch 9/60
# 135/135 [==============================] - 12s 89ms/step - loss: 364.5256 - val_loss: 1850.9933
# Epoch 10/60
# 135/135 [==============================] - 12s 89ms/step - loss: 352.8166 - val_loss: 875.7637
# Epoch 11/60
# 135/135 [==============================] - 12s 89ms/step - loss: 357.9359 - val_loss: 886.5522
# Epoch 12/60
# 135/135 [==============================] - 12s 90ms/step - loss: 346.9014 - val_loss: 926.1977
# Epoch 13/60
# 135/135 [==============================] - 12s 90ms/step - loss: 354.7733 - val_loss: 2053.9824
# Epoch 14/60
# 135/135 [==============================] - 12s 89ms/step - loss: 358.7584 - val_loss: 892.5346
# Epoch 15/60
# 135/135 [==============================] - 12s 90ms/step - loss: 365.2447 - val_loss: 838.3194
# Epoch 16/60
# 135/135 [==============================] - 12s 89ms/step - loss: 355.0745 - val_loss: 829.9934
# Epoch 17/60
# 135/135 [==============================] - 12s 89ms/step - loss: 355.7081 - val_loss: 2134.7295
# Epoch 18/60
# 135/135 [==============================] - 12s 90ms/step - loss: 348.9576 - val_loss: 2098.4368
# Epoch 19/60
# 135/135 [==============================] - 12s 89ms/step - loss: 356.6769 - val_loss: 1065.7660
# Epoch 20/60
# 135/135 [==============================] - 12s 89ms/step - loss: 348.9631 - val_loss: 1589.6617
# Epoch 21/60
# 135/135 [==============================] - 12s 89ms/step - loss: 351.5329 - val_loss: 1986.4797
# Epoch 22/60
# 135/135 [==============================] - 12s 90ms/step - loss: 354.3680 - val_loss: 1858.3243
# Epoch 23/60
# 135/135 [==============================] - 12s 88ms/step - loss: 349.6192 - val_loss: 905.9370
# Epoch 24/60
# 135/135 [==============================] - 12s 90ms/step - loss: 336.8641 - val_loss: 907.5074
# Epoch 25/60
# 135/135 [==============================] - 12s 90ms/step - loss: 346.3184 - val_loss: 1769.5265
# Epoch 26/60
# 135/135 [==============================] - 12s 90ms/step - loss: 342.3875 - val_loss: 856.9459
# Epoch 27/60
# 135/135 [==============================] - 12s 91ms/step - loss: 357.3351 - val_loss: 876.8748
# Epoch 28/60
# 135/135 [==============================] - 12s 89ms/step - loss: 331.8467 - val_loss: 949.5703
# Epoch 29/60
# 135/135 [==============================] - 12s 89ms/step - loss: 339.6292 - val_loss: 1990.8225
# Epoch 30/60
# 135/135 [==============================] - 12s 90ms/step - loss: 339.2765 - val_loss: 1026.6147
# Epoch 31/60
# 135/135 [==============================] - 12s 90ms/step - loss: 345.3143 - val_loss: 893.5186
# Epoch 32/60
# 135/135 [==============================] - 12s 89ms/step - loss: 350.5573 - val_loss: 838.7838
# Epoch 33/60
# 135/135 [==============================] - 12s 90ms/step - loss: 351.9122 - val_loss: 900.7225
# Epoch 34/60
# 135/135 [==============================] - 12s 89ms/step - loss: 338.9370 - val_loss: 2125.2280
# Epoch 35/60
# 135/135 [==============================] - 12s 89ms/step - loss: 344.0207 - val_loss: 858.7020
# Epoch 36/60
# 135/135 [==============================] - 12s 89ms/step - loss: 340.1347 - val_loss: 2237.0544
# Epoch 37/60
# 135/135 [==============================] - 12s 90ms/step - loss: 341.4375 - val_loss: 948.6526
# Epoch 38/60
# 135/135 [==============================] - 12s 90ms/step - loss: 335.5213 - val_loss: 1009.1443
# Epoch 39/60
# 135/135 [==============================] - 12s 90ms/step - loss: 332.9119 - val_loss: 1129.9362
# Epoch 40/60
# 135/135 [==============================] - 12s 89ms/step - loss: 331.9462 - val_loss: 1878.6371
# Epoch 41/60
# 135/135 [==============================] - 12s 89ms/step - loss: 339.9224 - val_loss: 1124.1256
# Epoch 42/60
# 135/135 [==============================] - 12s 89ms/step - loss: 339.8522 - val_loss: 902.1446
# Epoch 43/60
# 135/135 [==============================] - 12s 89ms/step - loss: 324.9844 - val_loss: 2018.1304
# Epoch 44/60
# 135/135 [==============================] - 12s 88ms/step - loss: 335.4896 - val_loss: 2021.3140
# Epoch 45/60
# 135/135 [==============================] - 12s 90ms/step - loss: 326.7258 - val_loss: 877.0134
# Epoch 46/60
# 135/135 [==============================] - 12s 89ms/step - loss: 331.7192 - val_loss: 1909.5825
# Epoch 47/60
# 135/135 [==============================] - 12s 91ms/step - loss: 339.2516 - val_loss: 881.5468
# Epoch 48/60
# 135/135 [==============================] - 12s 90ms/step - loss: 333.1294 - val_loss: 853.8943
# Epoch 49/60
# 135/135 [==============================] - 12s 88ms/step - loss: 328.4750 - val_loss: 1636.3805
# Epoch 50/60
# 135/135 [==============================] - 12s 89ms/step - loss: 313.4169 - val_loss: 961.9460
# Epoch 51/60
# 135/135 [==============================] - 12s 89ms/step - loss: 333.0099 - val_loss: 1626.0558
# Epoch 52/60
# 135/135 [==============================] - 12s 90ms/step - loss: 323.9048 - val_loss: 893.4598
# Epoch 53/60
# 135/135 [==============================] - 12s 90ms/step - loss: 336.5301 - val_loss: 1866.4648
# Epoch 54/60
# 135/135 [==============================] - 12s 89ms/step - loss: 325.3374 - val_loss: 944.8150
# Epoch 55/60
# 135/135 [==============================] - 12s 90ms/step - loss: 325.6873 - val_loss: 1367.1174
# Epoch 56/60
# 135/135 [==============================] - 12s 90ms/step - loss: 328.3073 - val_loss: 961.6001
# Epoch 57/60
# 135/135 [==============================] - 12s 91ms/step - loss: 321.5865 - val_loss: 909.7004
# Epoch 58/60
# 135/135 [==============================] - 12s 90ms/step - loss: 332.8340 - val_loss: 871.0014
# Epoch 59/60
# 135/135 [==============================] - 12s 90ms/step - loss: 312.9932 - val_loss: 890.4240
# Epoch 60/60
# 135/135 [==============================] - 12s 89ms/step - loss: 314.6320 - val_loss: 896.9428

# %%
# Plot loss vs epochs

plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Loss Plots")

plt.show()

# %%
# Randomly select 1000 images from our 3000 image dataset

seed_2 = random.sample(range(0,3000),1000)

# %%
# Obtain the embeddings for 1000 images

embeddings = encoder(tf.cast(image_data[seed_2] ,tf.float32)/255.0).mean()

# %%
# Plot the embeddings

x = embeddings[...,0]
y = embeddings[...,1]
plt.scatter(x,y)
plt.xlim(-18,18)
plt.ylim(-18,18)
plt.show()

# %%
# Randomly select 4 images from the dataset

seed_3 = random.sample(range(0,1000),4)

# %%
# Plot the original image and the reconstructed image

plt.figure(figsize=(8,10))
for i, v in enumerate(seed_3):
  plt.subplot(4,2,2*i+1)
  plt.imshow(image_data[v])
  plt.title('Original Image')
  plt.axis('off')

  im = tf.expand_dims(image_data[v],0)
  im = tf.cast(im, tf.float32)/255.
  r_im = tf.squeeze(VAE(im).mean())
  plt.subplot(4,2,2*i+2)
  plt.imshow(r_im)
  plt.title('Reconstructed Image')
  plt.axis('off')

# %%
# Sample embeddings randomly within a box of z_1 ~ (-15,15) and z_2 ~ (-15,15)

uniform_embedding = tfd.Uniform(low=-15.0, high=15.0)
random_embeddings_1 = tf.expand_dims(uniform_embedding.sample(6), axis = -1)
random_embeddings_2 = tf.expand_dims(uniform_embedding.sample(6), axis = -1)
random_embeddings = tf.concat([random_embeddings_1, random_embeddings_2], axis = -1)
print(random_embeddings.numpy())
# Out:
# [[ -5.8315945   6.860586 ]
#  [  5.8927994 -10.346661 ]
#  [  3.7677097   7.957035 ]
#  [ -9.6124325  -2.329999 ]
#  [-11.898312   14.875137 ]
#  [  5.214283   -7.807435 ]]

# %%
# Plot the embeddings

plt.scatter(random_embeddings_1, random_embeddings_2)
plt.xlim(-18,18)
plt.ylim(-18,18)
plt.show()

# %%
# Decode the embeddings and get the corresponding contour plots

new_images = decoder(random_embeddings).mean()

plt.figure(figsize=(12,8))
for i in range(6):
  plt.subplot(1,6,i+1)
  plt.imshow(new_images[i])
  plt.axis('off')
  plt.title(i+1)

# %%
# Function to create animation

import matplotlib.animation as anim
from IPython.display import HTML


def get_animation(latent_size, decoder, interpolation_length=500):
    assert latent_size >= 2, "Latent space must be at least 2-dimensional for plotting"
    fig = plt.figure(figsize=(9, 4))  
    ax1 = fig.add_subplot(1,2,1)
    ax1.set_xlim([-18, 18])
    ax1.set_ylim([-18, 18])
    ax1.set_title("Latent space")
    ax1.axes.get_xaxis().set_visible(True)
    ax1.axes.get_yaxis().set_visible(True)
    ax2 = fig.add_subplot(1,2,2)
    ax2.set_title("Data space")
    ax2.axes.get_xaxis().set_visible(False)
    ax2.axes.get_yaxis().set_visible(False)

    # initializing a line variable 
    line, = ax1.plot([], [], marker='o')
    img2 = ax2.imshow(np.zeros((36, 36, 3)))

    freqs = np.random.uniform(low=0.1, high=0.2, size=(latent_size,))
    phases = np.random.randn(latent_size)
    input_points = np.arange(interpolation_length)
    latent_coords = []
    for i in range(latent_size):
        latent_coords.append(17 * np.sin((freqs[i]*input_points + phases[i])).astype(np.float32))

    def animate(i): 
        z = tf.constant([coord[i] for coord in latent_coords])
        img_out = np.squeeze(decoder(z[np.newaxis, ...]).mean().numpy())
        line.set_data(z.numpy()[0], z.numpy()[1])
        img2.set_data(np.clip(img_out, 0, 1))
        return (line, img2)

    return anim.FuncAnimation(fig, animate, frames=interpolation_length, 
                              repeat=False, blit=True, interval=150)

# %%
# Create the animation
latent_size = latent_dim
a = get_animation(latent_size, decoder, interpolation_length=200)
HTML(a.to_html5_video())
# Out:
# <video width="648" height="288" controls autoplay>
#   <source type="video/mp4" src="...
